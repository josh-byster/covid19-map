# %%
import json
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from math import log

with open("./api_token.txt") as f:
    mapbox_access_token = f.read()

# %%
with open("./all.json") as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data=data)
df["Date"] = pd.to_datetime(df.Date)
nonzero_cases = df[(df["Cases"] > 0)]

# %%
nonzero_cases[(nonzero_cases['Date'] == "03/13/2020") & (nonzero_cases['Status'] == "confirmed")].groupby(["Country"]).sum().to_dict()
# Out:
# {'Lat': {'Afghanistan': 33.0,
#   'Albania': 41.1533,
#   'Algeria': 28.0339,
#   'Andorra': 42.5063,
#   'Antigua and Barbuda': 17.0608,
#   'Argentina': -38.4161,
#   'Armenia': 40.0691,
#   'Aruba': 12.5211,
#   'Australia': -255.9695,
#   'Austria': 47.5162,
#   'Azerbaijan': 40.1431,
#   'Bahrain': 26.0275,
#   'Bangladesh': 23.685,
#   'Belarus': 53.7098,
#   'Belgium': 50.8333,
#   'Bhutan': 27.5142,
#   'Bolivia': -16.2902,
#   'Bosnia and Herzegovina': 43.9159,
#   'Brazil': -14.235,
#   'Brunei': 4.5353,
#   'Bulgaria': 42.7339,
#   'Burkina Faso': 12.2383,
#   'Cambodia': 11.55,
#   'Cameroon': 3.848,
#   'Canada': 398.3247,
#   'Cayman Islands': 19.3133,
#   'Chile': -35.6751,
#   'China': 1083.3366999999998,
#   'Colombia': 4.5709,
#   'Congo (Kinshasa)': -4.0383,
#   'Costa Rica': 9.7489,
#   "Cote d'Ivoire": 7.54,
#   'Croatia': 45.1,
#   'Cruise Ship': 35.4437,
#   'Cuba': 22.0,
#   'Cyprus': 35.1264,
#   'Czechia': 49.8175,
#   'Denmark': 118.1565,
#   'Dominican Republic': 18.7357,
#   'Ecuador': -1.8312,
#   'Egypt': 26.0,
#   'Estonia': 58.5953,
#   'Ethiopia': 9.145,
#   'Finland': 64.0,
#   'France': 64.5187,
#   'French Guiana': 3.9339,
#   'Georgia': 42.3154,
#   'Germany': 51.0,
#   'Greece': 39.0742,
#   'Guadeloupe': 16.265,
#   'Guinea': 9.9456,
#   'Guyana': 5.0,
#   'Holy See': 41.9029,
#   'Honduras': 15.2,
#   'Hungary': 47.1625,
#   'Iceland': 64.9631,
#   'India': 21.0,
#   'Indonesia': -0.7893,
#   'Iran': 32.0,
#   'Iraq': 33.0,
#   'Ireland': 53.1424,
#   'Israel': 31.0,
#   'Italy': 43.0,
#   'Jamaica': 18.1096,
#   'Japan': 36.0,
#   'Jordan': 31.24,
#   'Kazakhstan': 48.0196,
#   'Kenya': -0.0236,
#   'Korea, South': 36.0,
#   'Kuwait': 29.5,
#   'Latvia': 56.8796,
#   'Lebanon': 33.8547,
#   'Liechtenstein': 47.14,
#   'Lithuania': 55.1694,
#   'Luxembourg': 49.8153,
#   'Malaysia': 2.5,
#   'Maldives': 3.2028,
#   'Malta': 35.9375,
#   'Martinique': 14.6415,
#   'Mexico': 23.6345,
#   'Moldova': 47.4116,
#   'Monaco': 43.7333,
#   'Mongolia': 46.8625,
#   'Morocco': 31.7917,
#   'Nepal': 28.1667,
#   'Netherlands': 52.1326,
#   'New Zealand': -40.9006,
#   'Nigeria': 9.082,
#   'North Macedonia': 41.6086,
#   'Norway': 60.472,
#   'Oman': 21.0,
#   'Pakistan': 30.3753,
#   'Panama': 8.538,
#   'Paraguay': -23.4425,
#   'Peru': -9.19,
#   'Philippines': 13.0,
#   'Poland': 51.9194,
#   'Portugal': 39.3999,
#   'Qatar': 25.3548,
#   'Reunion': -21.1151,
#   'Romania': 45.9432,
#   'Russia': 60.0,
#   'San Marino': 43.9424,
#   'Saudi Arabia': 24.0,
#   'Senegal': 14.4974,
#   'Serbia': 44.0165,
#   'Singapore': 1.2833,
#   'Slovakia': 48.669,
#   'Slovenia': 46.1512,
#   'South Africa': -30.5595,
#   'Spain': 40.0,
#   'Sri Lanka': 7.0,
#   'Sudan': 12.8628,
#   'Sweden': 63.0,
#   'Switzerland': 46.8182,
#   'Taiwan*': 23.7,
#   'Thailand': 15.0,
#   'Togo': 8.6195,
#   'Tunisia': 34.0,
#   'Turkey': 38.9637,
#   'US': 2046.8186000000003,
#   'Ukraine': 48.3794,
#   'United Arab Emirates': 24.0,
#   'United Kingdom': 140.89120000000003,
#   'Vietnam': 16.0},
#  'Lon': {'Afghanistan': 65.0,
#   'Albania': 20.1683,
#   'Algeria': 1.6596,
#   'Andorra': 1.5218,
#   'Antigua and Barbuda': -61.7964,
#   'Argentina': -63.6167,
#   'Armenia': 45.0382,
#   'Aruba': -69.9683,
#   'Australia': 1129.862,
#   'Austria': 14.5501,
#   'Azerbaijan': 47.5769,
#   'Bahrain': 50.55,
#   'Bangladesh': 90.3563,
#   'Belarus': 27.9534,
#   'Belgium': 4.0,
#   'Bhutan': 90.4336,
#   'Bolivia': -63.5887,
#   'Bosnia and Herzegovina': 17.6791,
#   'Brazil': -51.9253,
#   'Brunei': 114.728,
#   'Bulgaria': 25.4858,
#   'Burkina Faso': -1.5616,
#   'Cambodia': 104.917,
#   'Cameroon': 11.5021,
#   'Canada': -792.9611,
#   'Cayman Islands': -81.2546,
#   'Chile': -71.543,
#   'China': 3684.4161000000004,
#   'Colombia': -74.2973,
#   'Congo (Kinshasa)': 21.7587,
#   'Costa Rica': -83.7534,
#   "Cote d'Ivoire": -5.5471,
#   'Croatia': 15.2,
#   'Cruise Ship': 139.638,
#   'Cuba': -80.0,
#   'Cyprus': 33.4299,
#   'Czechia': 15.473,
#   'Denmark': 2.589999999999999,
#   'Dominican Republic': -70.1627,
#   'Ecuador': -78.1834,
#   'Egypt': 30.0,
#   'Estonia': 25.0136,
#   'Ethiopia': 40.4897,
#   'Finland': 26.0,
#   'France': 25.737300000000005,
#   'French Guiana': -53.1258,
#   'Georgia': 43.3569,
#   'Germany': 9.0,
#   'Greece': 21.8243,
#   'Guadeloupe': -61.551,
#   'Guinea': -9.6966,
#   'Guyana': -58.75,
#   'Holy See': 12.4534,
#   'Honduras': -86.2419,
#   'Hungary': 19.5033,
#   'Iceland': -19.0208,
#   'India': 78.0,
#   'Indonesia': 113.921,
#   'Iran': 53.0,
#   'Iraq': 44.0,
#   'Ireland': -7.6921,
#   'Israel': 35.0,
#   'Italy': 12.0,
#   'Jamaica': -77.2975,
#   'Japan': 138.0,
#   'Jordan': 36.51,
#   'Kazakhstan': 66.9237,
#   'Kenya': 37.9062,
#   'Korea, South': 128.0,
#   'Kuwait': 47.75,
#   'Latvia': 24.6032,
#   'Lebanon': 35.8623,
#   'Liechtenstein': 9.55,
#   'Lithuania': 23.8813,
#   'Luxembourg': 6.1296,
#   'Malaysia': 112.5,
#   'Maldives': 73.2207,
#   'Malta': 14.3754,
#   'Martinique': -61.0242,
#   'Mexico': -102.553,
#   'Moldova': 28.3699,
#   'Monaco': 7.4167,
#   'Mongolia': 103.847,
#   'Morocco': -7.0926,
#   'Nepal': 84.25,
#   'Netherlands': 5.2913,
#   'New Zealand': 174.886,
#   'Nigeria': 8.6753,
#   'North Macedonia': 21.7453,
#   'Norway': 8.4689,
#   'Oman': 57.0,
#   'Pakistan': 69.3451,
#   'Panama': -80.7821,
#   'Paraguay': -58.4438,
#   'Peru': -75.0152,
#   'Philippines': 122.0,
#   'Poland': 19.1451,
#   'Portugal': -8.2245,
#   'Qatar': 51.1839,
#   'Reunion': 55.5364,
#   'Romania': 24.9668,
#   'Russia': 90.0,
#   'San Marino': 12.4578,
#   'Saudi Arabia': 45.0,
#   'Senegal': -14.4524,
#   'Serbia': 21.0059,
#   'Singapore': 103.833,
#   'Slovakia': 19.699,
#   'Slovenia': 14.9955,
#   'South Africa': 22.9375,
#   'Spain': -4.0,
#   'Sri Lanka': 81.0,
#   'Sudan': 30.2176,
#   'Sweden': 16.0,
#   'Switzerland': 8.2275,
#   'Taiwan*': 121.0,
#   'Thailand': 101.0,
#   'Togo': 0.8248,
#   'Tunisia': 9.0,
#   'Turkey': 35.2433,
#   'US': -4662.490099999998,
#   'Ukraine': 31.1656,
#   'United Arab Emirates': 54.0,
#   'United Kingdom': -11.154,
#   'Vietnam': 108.0},
#  'Cases': {'Afghanistan': 7,
#   'Albania': 33,
#   'Algeria': 26,
#   'Andorra': 1,
#   'Antigua and Barbuda': 1,
#   'Argentina': 31,
#   'Armenia': 8,
#   'Aruba': 2,
#   'Australia': 200,
#   'Austria': 504,
#   'Azerbaijan': 15,
#   'Bahrain': 189,
#   'Bangladesh': 3,
#   'Belarus': 27,
#   'Belgium': 559,
#   'Bhutan': 1,
#   'Bolivia': 3,
#   'Bosnia and Herzegovina': 13,
#   'Brazil': 151,
#   'Brunei': 37,
#   'Bulgaria': 23,
#   'Burkina Faso': 2,
#   'Cambodia': 5,
#   'Cameroon': 2,
#   'Canada': 193,
#   'Cayman Islands': 1,
#   'Chile': 43,
#   'China': 80945,
#   'Colombia': 13,
#   'Congo (Kinshasa)': 2,
#   'Costa Rica': 23,
#   "Cote d'Ivoire": 1,
#   'Croatia': 32,
#   'Cruise Ship': 696,
#   'Cuba': 4,
#   'Cyprus': 14,
#   'Czechia': 141,
#   'Denmark': 804,
#   'Dominican Republic': 5,
#   'Ecuador': 17,
#   'Egypt': 80,
#   'Estonia': 79,
#   'Ethiopia': 1,
#   'Finland': 155,
#   'France': 3667,
#   'French Guiana': 5,
#   'Georgia': 25,
#   'Germany': 3675,
#   'Greece': 190,
#   'Guadeloupe': 1,
#   'Guinea': 1,
#   'Guyana': 1,
#   'Holy See': 1,
#   'Honduras': 2,
#   'Hungary': 19,
#   'Iceland': 134,
#   'India': 82,
#   'Indonesia': 69,
#   'Iran': 11364,
#   'Iraq': 101,
#   'Ireland': 90,
#   'Israel': 161,
#   'Italy': 17660,
#   'Jamaica': 8,
#   'Japan': 701,
#   'Jordan': 1,
#   'Kazakhstan': 4,
#   'Kenya': 1,
#   'Korea, South': 7979,
#   'Kuwait': 80,
#   'Latvia': 17,
#   'Lebanon': 77,
#   'Liechtenstein': 1,
#   'Lithuania': 6,
#   'Luxembourg': 34,
#   'Malaysia': 197,
#   'Maldives': 9,
#   'Malta': 12,
#   'Martinique': 3,
#   'Mexico': 12,
#   'Moldova': 6,
#   'Monaco': 2,
#   'Mongolia': 1,
#   'Morocco': 7,
#   'Nepal': 1,
#   'Netherlands': 804,
#   'New Zealand': 5,
#   'Nigeria': 2,
#   'North Macedonia': 14,
#   'Norway': 996,
#   'Oman': 19,
#   'Pakistan': 28,
#   'Panama': 27,
#   'Paraguay': 6,
#   'Peru': 28,
#   'Philippines': 64,
#   'Poland': 68,
#   'Portugal': 112,
#   'Qatar': 320,
#   'Reunion': 5,
#   'Romania': 89,
#   'Russia': 45,
#   'San Marino': 80,
#   'Saudi Arabia': 86,
#   'Senegal': 10,
#   'Serbia': 35,
#   'Singapore': 200,
#   'Slovakia': 32,
#   'Slovenia': 141,
#   'South Africa': 24,
#   'Spain': 5232,
#   'Sri Lanka': 6,
#   'Sudan': 1,
#   'Sweden': 814,
#   'Switzerland': 1139,
#   'Taiwan*': 50,
#   'Thailand': 75,
#   'Togo': 1,
#   'Tunisia': 16,
#   'Turkey': 5,
#   'US': 2179,
#   'Ukraine': 3,
#   'United Arab Emirates': 85,
#   'United Kingdom': 801,
#   'Vietnam': 47}}

# %%
MARKER_SIZE_MAX = 100
LOG_SHIFT = 20
# What is the max number of cases in the entire dataset?
HIGHEST_CASE_COUNT = nonzero_cases.groupby(["Lat","Lon","Province"]).sum().max()
# Normalize the data point
def normalize(x,maxval):
    def normal(y):
        return log((y+LOG_SHIFT)/LOG_SHIFT,10)
    return MARKER_SIZE_MAX*normal(x) / normal(maxval)

def case_list_for_date(cur_date):
    grouped_cases = nonzero_cases[nonzero_cases['Date'] < cur_date].groupby(["Lat","Lon","Province"])
    cur_cases = grouped_cases.sum().to_dict()["Cases"]
    return cur_cases.items()

def get_map_for_date(cur_date):
    cur_cases = case_list_for_date(cur_date)
    lat_list = list(map(lambda x: x[0][0], cur_cases))
    lon_list = list(map(lambda x: x[0][1], cur_cases))
    name_list = list(map(lambda x: x[0][2], cur_cases))
    cases_list = list(map(lambda x: x[1], cur_cases))
    text = list(map(lambda x: f"{x[1]}" if x[1]>100 else "", cur_cases))
    size_list = [normalize(c,HIGHEST_CASE_COUNT) for c in cases_list]

    fig = go.Figure(go.Scattermapbox(
            lat=lat_list,
            lon=lon_list,
            mode='markers+text',
            marker=go.scattermapbox.Marker(
                size=size_list,
                sizemin=1,
                colorscale="Bluered",
                color=size_list,
                cmin=0,
                cmax=MARKER_SIZE_MAX,
                symbol="circle",
                showscale=True,
                colorbar=dict(title="# of Cases", tickvals=[25,50,75,99], ticktext=["50", "250", "1000","4000"])
            ),
            text=text
        ))


    fig.update_layout(
        margin = {"l": 20,"r":20,"t":50,"b":20},
        title=f"Cumulative Number of Coronavirus Cases on {cur_date}",
        autosize=False,
        width=1600,
        height=900,
        hovermode='closest',
        mapbox=dict(
            accesstoken=mapbox_access_token,
            bearing=0,
            center=dict(
                lat=39.82,
                lon=-98.57
            ),
            pitch=0,
            zoom=4
        )
    )

    return fig

# %%
get_map_for_date("03-14-2020")
# Out:
# <div>
#
#
#             <div id="5d0e0bf9-1bea-4073-b7e0-c92fdb7ea963" class="plotly-graph-div" style="height:900px; width:1600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5d0e0bf9-1bea-4073-b7e0-c92fdb7ea963")) {
#                     Plotly.newPlot(
#                         '5d0e0bf9-1bea-4073-b7e0-c92fdb7ea963',
#                         [{"lat": [21.0943, 21.307, 26.1901, 26.663, 26.8946, 27.4799, 27.7663, 27.9904, 29.028, 29.5693, 29.6499, 29.7752, 30.5773, 30.769, 31.0545, 31.1695, 32.3182, 32.7157, 32.7416, 32.7957, 32.8162, 33.0406, 33.1795, 33.2918, 33.7298, 33.7879, 33.8034, 33.8569, 33.8999, 33.9533, 34.0132, 34.0522, 34.2515, 34.3672, 34.8405, 34.8606, 34.9697, 35.1269, 35.4437, 35.5653, 35.6301, 35.7211, 35.7478, 35.8032, 35.9179, 36.0796, 36.1162, 36.1343, 36.1593, 36.5761, 36.9859, 37.2519, 37.3541, 37.563, 37.6017, 37.6489, 37.6681, 37.7693, 37.7749, 37.8534, 38.0606, 38.1938, 38.3135, 38.4333, 38.4561, 38.4747, 38.5266, 38.578, 38.6103, 38.7646, 38.8454, 38.8974, 38.9072, 38.9085, 38.9108, 39.0598, 39.0639, 39.0916, 39.1547, 39.2587, 39.3185, 39.5839, 39.5912, 39.7392, 39.8065, 39.8362, 39.8494, 39.9078, 40.15, 40.229, 40.2989, 40.3495, 40.3888, 40.5608, 40.5908, 40.6546, 40.7128, 40.745, 40.7453, 40.7909, 40.9263, 40.9629, 40.9849, 41.122, 41.1254, 41.1489, 41.3148, 41.5978, 41.6699, 41.6739, 41.6809, 41.7377, 41.8586, 41.8882, 42.0115, 42.1657, 42.1767, 42.2302, 42.3118, 42.3345, 42.3601, 42.4672, 42.6953, 42.756, 42.9931, 43.0279, 43.0324, 43.1261, 43.3266, 43.4525, 43.9088, 44.0459, 44.2405, 44.2685, 44.2998, 44.572, 44.6939, 44.8254, 44.8446, 44.9964, 45.547, 45.6945, 45.7466, 45.775, 46.9219, 47.0676, 47.175, 47.1981, 47.4009, 47.5289, 47.6062, 47.7425, 48.033, 61.3707], "lon": [-157.498, -157.858, -80.3659, -81.9535, -81.9098, -82.3452, -81.6868, -82.3018, -81.0755, -95.8143, -90.1121, -95.3103, -86.6611, -86.9824, -97.5635, -91.8678, -86.9023, -117.161, -89.6787, -79.7848, -111.285, -83.6431, -96.493, -112.429, -111.431, -117.853, -84.3963, -80.945, -84.5641, -117.396, -85.1479, -118.244, -84.4803, -80.5883, -106.248, -81.9535, -92.3731, -89.9253, 139.638, -96.9289, -79.8064, -79.1781, -86.6923, -78.5661, -86.8622, -115.094, -119.682, -86.822, -95.941, -120.988, -119.232, -119.696, -121.955, -122.326, -121.719, -122.665, -84.6701, -78.17, -122.419, -121.902, -84.4803, -85.6435, -117.055, -84.3542, -92.2884, -121.354, -96.7265, -122.989, -90.4125, -121.902, -94.8521, -77.0268, -77.0369, -77.2405, -104.472, -105.311, -76.8021, -120.804, -77.2405, -104.939, -75.5071, -76.3637, -106.064, -104.99, -86.5401, -86.1752, -86.2583, -75.3879, -111.862, -75.3879, -74.521, -88.9861, -82.7649, -119.604, -77.2098, -73.5594, -74.006, -123.869, -74.0535, -121.847, -74.077, -112.095, -72.6151, -73.7949, -98.2681, -73.983, -96.1951, -72.7554, -91.5984, -75.2479, -71.5118, -87.6976, -74.3118, -71.4774, -93.2105, -74.9481, -71.1449, -71.5301, -73.1822, -122.765, -71.0589, -71.2874, -121.614, -107.302, -71.0498, -73.135, -73.936, -123.249, -84.5361, -71.5639, -71.826, -72.7107, -114.479, -89.6165, -99.4388, -122.071, -69.3819, -93.7842, -122.593, -93.0616, -123.139, -93.9002, -122.519, -118.761, -110.454, -122.13, -120.932, -119.373, -121.491, -99.784, -122.332, -123.304, -121.834, -152.404], "marker": {"cmax": 100, "cmin": 0, "color": [7.61138125444221, 3.1615726722685826, 6.788704150708271, 5.9349753918968124, 1.1036885084175194, 3.1615726722685826, 45.27573361688738, 12.659139906323691, 2.15602369813599, 13.916192576223544, 1.1036885084175194, 16.238345249946644, 2.15602369813599, 5.0477586518814785, 41.27336156699596, 31.918115770278558, 5.0477586518814785, 31.07499480869406, 2.15602369813599, 3.1615726722685826, 5.9349753918968124, 42.85836881157797, 1.1036885084175194, 27.683179668643888, 22.04563755305709, 30.49493412479159, 15.107053166204034, 25.59359104666404, 5.0477586518814785, 2.15602369813599, 4.1243191224257405, 42.51561790332218, 1.1036885084175194, 3.1615726722685826, 14.51945838492236, 1.1036885084175194, 11.328101472443207, 2.15602369813599, 84.87117219399946, 7.61138125444221, 27.007871992775122, 4.1243191224257405, 31.359541040663824, 6.788704150708271, 5.0477586518814785, 6.788704150708271, 84.65776375110427, 2.15602369813599, 3.1615726722685826, 34.52111371293241, 2.15602369813599, 3.1615726722685826, 58.022045604 ...

# %%
date_list = pd.date_range(start='2020-01-24', end='2020-3-14', tz="UTC")
for (frame, date) in enumerate(date_list):
    print(date)
    figure = get_map_for_date(date.strftime('%Y/%m/%d'))
    figure.write_image(f"covid_imgs/img-{frame:03d}.png")
# Out:
# 2020-01-24 00:00:00+00:00
# [4.996996444695609]
# 2020-01-25 00:00:00+00:00
# [2.6619095042151066, 7.076808932954485]
# 2020-01-26 00:00:00+00:00
# [4.996996444695609, 8.951701059981758]
# 2020-01-27 00:00:00+00:00
# [2.6619095042151066, 2.6619095042151066, 2.6619095042151066, 7.076808932954485, 10.658456510396194]
# 2020-01-28 00:00:00+00:00
# [4.996996444695609, 4.996996444695609, 4.996996444695609, 8.951701059981758, 12.224765418138455]
# 2020-01-29 00:00:00+00:00
# [7.076808932954485, 7.076808932954485, 7.076808932954485, 10.658456510396194, 13.671994932364832]
# 2020-01-30 00:00:00+00:00
# [8.951701059981758, 8.951701059981758, 8.951701059981758, 12.224765418138455, 15.01697891109911]
# 2020-01-31 00:00:00+00:00
# [10.658456510396194, 10.658456510396194, 10.658456510396194, 13.671994932364832, 16.27321604089236]
# 2020-02-01 00:00:00+00:00
# [12.224765418138455, 12.224765418138455, 12.224765418138455, 2.6619095042151066, 16.27321604089236, 17.451696551646908]

# %%
normal_inverse(20)
# Out:
# 1999999999999999999980

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-ed9d4e719f00> in <module>
# ----> 1 normal_inverse(20)
#
# NameError: name 'normal_inverse' is not defined
