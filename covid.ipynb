# %%
import json
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from math import log

with open("./api_token.txt") as f:
    mapbox_access_token = f.read()

# %%
with open("./all.json") as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data=data)
df["Date"] = pd.to_datetime(df.Date)
nonzero_cases = df[(df["Cases"] > 0) & (df["Status"] == "confirmed")]

# %%
# Out:
#                                 Province                      Date  Cases  \
# Lat     Lon      Country
# 19.1959 109.7450 China            Hainan 2020-03-13 00:00:00+00:00    168
# 22.1667 113.5500 China             Macau 2020-03-13 00:00:00+00:00     10
# 22.3000 114.2000 China         Hong Kong 2020-03-13 00:00:00+00:00    134
# 23.3417 113.4240 China         Guangdong 2020-03-13 00:00:00+00:00   1356
# 23.8298 108.7880 China           Guangxi 2020-03-13 00:00:00+00:00    252
# 24.9740 101.4870 China            Yunnan 2020-03-13 00:00:00+00:00    174
# 26.0789 117.9870 China            Fujian 2020-03-13 00:00:00+00:00    296
# 26.8154 106.8750 China           Guizhou 2020-03-13 00:00:00+00:00    146
# 27.6104 111.7090 China             Hunan 2020-03-13 00:00:00+00:00   1018
# 27.6140 115.7220 China           Jiangxi 2020-03-13 00:00:00+00:00    935
# 29.1832 120.0930 China          Zhejiang 2020-03-13 00:00:00+00:00   1215
# 30.0572 107.8740 China         Chongqing 2020-03-13 00:00:00+00:00    576
# 30.6171 102.7100 China           Sichuan 2020-03-13 00:00:00+00:00    539
# 30.9756 112.2710 China             Hubei 2020-03-13 00:00:00+00:00  67786
# 31.2020 121.4490 China          Shanghai 2020-03-13 00:00:00+00:00    346
# 31.6927 88.0924  China             Tibet 2020-03-13 00:00:00+00:00      1
# 31.8257 117.2260 China             Anhui 2020-03-13 00:00:00+00:00    990
# 32.9711 119.4550 China           Jiangsu 2020-03-13 00:00:00+00:00    631
# 33.8820 113.6140 China             Henan 2020-03-13 00:00:00+00:00   1273
# 35.1917 108.8700 China           Shaanxi 2020-03-13 00:00:00+00:00    245
# 35.7452 95.9956  China           Qinghai 2020-03-13 00:00:00+00:00     18
# 36.3427 118.1500 China          Shandong 2020-03-13 00:00:00+00:00    760
# 37.2692 106.1650 China           Ningxia 2020-03-13 00:00:00+00:00     75
# 37.5777 112.2920 China            Shanxi 2020-03-13 00:00:00+00:00    133
# 37.8099 101.0580 China             Gansu 2020-03-13 00:00:00+00:00    127
# 39.3054 117.3230 China           Tianjin 2020-03-13 00:00:00+00:00    136
# 39.5490 116.1310 China             Hebei 2020-03-13 00:00:00+00:00    318
# 40.1824 116.4140 China           Beijing 2020-03-13 00:00:00+00:00    436
# 41.1129 85.2401  China          Xinjiang 2020-03-13 00:00:00+00:00     76
# 41.2956 122.6080 China          Liaoning 2020-03-13 00:00:00+00:00    125
# 43.6661 126.1920 China             Jilin 2020-03-13 00:00:00+00:00     93
# 44.0935 113.9450 China    Inner Mongolia 2020-03-13 00:00:00+00:00     75
# 47.8620 127.7610 China      Heilongjiang 2020-03-13 00:00:00+00:00    482
#
#                              Status
# Lat     Lon      Country
# 19.1959 109.7450 China    confirmed
# 22.1667 113.5500 China    confirmed
# 22.3000 114.2000 China    confirmed
# 23.3417 113.4240 China    confirmed
# 23.8298 108.7880 China    confirmed
# 24.9740 101.4870 China    confirmed
# 26.0789 117.9870 China    confirmed
# 26.8154 106.8750 China    confirmed
# 27.6104 111.7090 China    confirmed
# 27.6140 115.7220 China    confirmed
# 29.1832 120.0930 China    confirmed
# 30.0572 107.8740 China    confirmed
# 30.6171 102.7100 China    confirmed
# 30.9756 112.2710 China    confirmed
# 31.2020 121.4490 China    confirmed
# 31.6927 88.0924  China    confirmed
# 31.8257 117.2260 China    confirmed
# 32.9711 119.4550 China    confirmed
# 33.8820 113.6140 China    confirmed
# 35.1917 108.8700 China    confirmed
# 35.7452 95.9956  China    confirmed
# 36.3427 118.1500 China    confirmed
# 37.2692 106.1650 China    confirmed
# 37.5777 112.2920 China    confirmed
# 37.8099 101.0580 China    confirmed
# 39.3054 117.3230 China    confirmed
# 39.5490 116.1310 China    confirmed
# 40.1824 116.4140 China    confirmed
# 41.1129 85.2401  China    confirmed
# 41.2956 122.6080 China    confirmed
# 43.6661 126.1920 China    confirmed
# 44.0935 113.9450 China    confirmed
# 47.8620 127.7610 China    confirmed

# %%
MARKER_SIZE_MAX = 100
LOG_SHIFT = 20
# What is the max number of cases in the entire dataset?
HIGHEST_CASE_COUNT = nonzero_cases[(nonzero_cases['Date'] == "03/13/2020")].groupby(["Lat","Lon","Country"]).sum().max()
# Normalize the data point
def normalize(x,maxval):
    def normal(y):
        return log((y+LOG_SHIFT)/LOG_SHIFT,10)
    return MARKER_SIZE_MAX*normal(x) / normal(maxval)

def case_list_for_date(cur_date):
    grouped_cases = nonzero_cases[nonzero_cases['Date'] == cur_date].groupby(["Lat","Lon","Country"])
    cur_cases = grouped_cases.sum().to_dict()["Cases"]
    return cur_cases.items()

def get_map_for_date(cur_date):
    cur_cases = case_list_for_date(cur_date)
    lat_list = list(map(lambda x: x[0][0], cur_cases))
    lon_list = list(map(lambda x: x[0][1], cur_cases))
    name_list = list(map(lambda x: x[0][2], cur_cases))
    cases_list = list(map(lambda x: x[1], cur_cases))
    text = list(map(lambda x: f"{x[1]}" if x[1]>100 else "", cur_cases))
    size_list = [normalize(c,HIGHEST_CASE_COUNT) for c in cases_list]

    fig = go.Figure(go.Scattermapbox(
            lat=lat_list,
            lon=lon_list,
            mode='markers+lines',
            marker=go.scattermapbox.Marker(
                size=size_list,
                sizemin=1,
                colorscale="Bluered",
                color=size_list,
                cmin=0,
                cmax=MARKER_SIZE_MAX,
                symbol="circle",
                showscale=True,
                colorbar=dict(title="# of Cases", tickvals=[25,50,75,99], ticktext=["50", "250", "1000","4000"])
            ),
            text=text
        ))


    fig.update_layout(
        margin = {"l": 20,"r":20,"t":50,"b":20},
        title=f"Cumulative Number of Coronavirus Cases on {cur_date}",
        autosize=False,
        width=1600,
        height=900,
        hovermode='closest',
        mapbox=dict(
            accesstoken=mapbox_access_token,
            bearing=0,
            center=dict(
                lat=39.82,
                lon=0.57
            ),
            pitch=0,
            zoom=1.5
        )
    )

    return fig

# %%
get_map_for_date("03-13-2020")
# Out:
# <div>
#
#
#             <div id="42a6ee8e-0fd7-49f4-aeca-875fe4711a95" class="plotly-graph-div" style="height:900px; width:1600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("
114.2, 113.424, -102.553, 90.3563, 121.0, 108.788, 45.0, 54.0, 101.487, 51.1839, 30.0, 50.55, 117.987, 106.875, 90.4336, 111.709, 115.722, -81.6868, 1.6596, 84.25, 120.093, 47.75, 107.874, 69.3451, 102.71, 112.271, 35.0, -97.5635, -91.8678, 121.449, 36.51, 88.0924, -7.0926, 117.226, 53.0, -86.9023, -89.6787, 119.455, 44.0, 65.0, -83.6431, -111.431, 35.8623, -80.945, 113.614, 9.0, -106.248, -92.3731, 33.4299, 108.87, 139.638, 139.638, -96.9289, -79.8064, 95.9956, -86.6923, 14.3754, 128.0, 138.0, -119.682, -5.3536, 118.15, 106.165, 112.292, -122.665, -122.665, -84.6701, -78.17, 101.058, -117.055, -92.2884, -96.7265, -77.0268, 35.2433, -105.311, -76.8021, 21.8243, 117.323, -75.5071, -8.2245, 116.131, -86.2583, -4.0, 45.0382, 47.5769, -111.862, 116.414, -74.521, -88.9861, -82.7649, -77.2098, 85.2401, -98.2681, 20.1683, 122.608, -72.7554, 21.7453, -71.5118, 12.4534, -93.2105, -74.9481, -71.5301, 43.3569, 1.5218, 25.4858, -107.302, 12.0, -84.5361, -71.5639, 126.192, 7.4167, 17.6791, 12.4578, 21.0059, -72.7107, 113.945, -114.479, -89.6165, -99.4388, -122.071, -69.3819, 15.2, -93.9002, 24.9668, 14.9955, 2.2137, -66.4619, 8.2275, 103.847, -110.454, 9.55, 19.5033, -121.491, 28.3699, 14.5501, -99.784, 127.761, 66.9237, 31.1656, 19.699, -123.121, -2.3644, 6.1296, 15.473, 4.0, 9.0, -85.3232, 19.1451, 5.2913, -106.451, -73.5491, -7.6921, 27.9534, -98.8139, -116.576, 23.8813, -3.436, 9.5018, 24.6032, 25.0136, 90.0, 8.4689, -152.404, -6.9118, 16.0, 26.0, -19.0208], "marker" ...

# %%
date_list = pd.date_range(start='2020-01-24', end='2020-3-14', tz="UTC")
for (frame, date) in enumerate(date_list):
    print(date)
    figure = get_map_for_date(date.strftime('%Y/%m/%d'))
    figure.write_image(f"covid_imgs/img-{frame:03d}.png")
# Out:
# 2020-01-24 00:00:00+00:00
# [4.996996444695609]
# 2020-01-25 00:00:00+00:00
# [2.6619095042151066, 7.076808932954485]
# 2020-01-26 00:00:00+00:00
# [4.996996444695609, 8.951701059981758]
# 2020-01-27 00:00:00+00:00
# [2.6619095042151066, 2.6619095042151066, 2.6619095042151066, 7.076808932954485, 10.658456510396194]
# 2020-01-28 00:00:00+00:00
# [4.996996444695609, 4.996996444695609, 4.996996444695609, 8.951701059981758, 12.224765418138455]
# 2020-01-29 00:00:00+00:00
# [7.076808932954485, 7.076808932954485, 7.076808932954485, 10.658456510396194, 13.671994932364832]
# 2020-01-30 00:00:00+00:00
# [8.951701059981758, 8.951701059981758, 8.951701059981758, 12.224765418138455, 15.01697891109911]
# 2020-01-31 00:00:00+00:00
# [10.658456510396194, 10.658456510396194, 10.658456510396194, 13.671994932364832, 16.27321604089236]
# 2020-02-01 00:00:00+00:00
# [12.224765418138455, 12.224765418138455, 12.224765418138455, 2.6619095042151066, 16.27321604089236, 17.451696551646908]

# %%
print(HIGHEST_CASE_COUNT)
# Out:
# Cases    67786
# dtype: int64
